# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder 
print('Version Seaborn : ' + sns.__version__)
tips = sns.load_dataset('tips') # Chargement des données tips
ec = LabelEncoder()
print('Feature Engineering Data Tips')
tips["sex"] = ec.fit_transform(tips['sex'].astype('str'))
tips["smoker"] = ec.fit_transform(tips['smoker'].astype('str'))
tips["day"] = ec.fit_transform(tips['day'].astype('str'))
tips["time"] = ec.fit_transform(tips['time'].astype('str'))
print('Normalization Data Tips')
tips_normalized = (tips-tips.min())/(tips.max()-tips.min())
# print('Standardization Data Tips')
tips_normalized.head(10)
# Out:
# Version Seaborn : 0.11.0
# Feature Engineering Data Tips
# Normalization Data Tips
#    total_bill       tip  sex  smoker       day  time  size
# 0    0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1    0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2    0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3    0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4    0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# 5    0.465438  0.412222  1.0     0.0  0.666667   0.0   0.6
# 6    0.119397  0.111111  1.0     0.0  0.666667   0.0   0.2
# 7    0.498743  0.235556  1.0     0.0  0.666667   0.0   0.6
# 8    0.250733  0.106667  1.0     0.0  0.666667   0.0   0.2
# 9    0.245287  0.247778  1.0     0.0  0.666667   0.0   0.2
