# %%
import numpy as np
import pandas as pd
import json
from urllib.request import urlopen
from bs4 import BeautifulSoup
from lib import nba_factory
nbaService = nba_factory.NbaService()
year = 2021
url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html".format(year)
player_stats = nbaService.getStats(url)
teamsName = nbaService.getTeamsName(player_stats)
# Per Game 
allTeamsPerGame = nbaService.getAllStats(teamsName,player_stats)
with open('nba_per_game.json', 'w') as outfile:
    json.dump(allTeamsPerGame, outfile)

# Total
url = "https://www.basketball-reference.com/leagues/NBA_{}_totals.html".format(year)
player_stats_total = nbaService.getStats(url)
allTeamsTotal = nbaService.getAllStats(teamsName,player_stats_total)
with open('nba_total.json', 'w') as outfile:
    json.dump(allTeamsTotal, outfile)

# Shooting
# Advanced
# Out:
# 2021
# https://www.basketball-reference.com/leagues/NBA_2021_per_game.html
# 528
# [{'team': 'MIA', 'players': [{'name': 'Precious Achiuwa', 'position': 'PF', 'age': '21', 'games': '31', 'games_started': '2', 'minutes_played_per_game': '14.2', 'field_goal_per_game': '2.4', 'field_goal_attempt_per_game': '4.2', 'field_goal_percent_per_game': '.573', 'three_points_field_goal_per_game': '0.0', 'three_points_field_goal_attempt_per_game': '0.0', 'three_points_field_goal_percent_per_game': '', 'two_points_field_goal_per_game': '2.4', 'two_points_field_goal_attempt_per_game': '4.2', 'two_points_field_goal_percent_per_game': '.573', 'effective_field_goal_percent_per_game': '.573', 'free_throws_per_game': '1.2', 'free_throws_attempt_per_game': '2.3', 'free_throws_percent_per_game': '.529', 'offensive_rebound_per_game': '1.3', 'defensive_rebound_per_game': '2.7', 'total_rebound_per_game': '4.0', 'assists_per_game': '0.6', 'steal_per_game': '0.4', 'block_per_game': '0.5', 'turnover_per_game': '1.0', 'personal_fouls_per_game': '1.8', 'points_per_game': '6.0'}, {'name': 'Bam Adebayo', 'position': 'C', 'age': '23', 'games': '29', 'games_started': '29', 'minutes_played_per_game': '33.9', 'field_goal_per_game': '7.3', 'field_goal_attempt_per_game': '12.9', 'field_goal_percent_per_game': '.570', 'three_points_field_goal_per_game': '0.1', 'three_points_field_goal_attempt_per_game': '0.2', 'three_points_field_goal_percent_per_game': '.333', 'two_points_field_goal_per_game': '7.3', 'two_points_field_goal_attempt_per_game': '12.7', 'two_points_field_goal_percent_per_game': '.573', 'effective_field_goal_percent_per_game': '.572', 'free_throws_per_game': '4.9', 'free_throws_attempt_per_game': '5.8', 'free_throws_percent_per_game': '.844', 'offensive_rebound_per_game': '2.0', 'defensive_rebound_per_game': '7.4', 'total_rebound_per_game': '9.5', 'assists_per_game': '5.5', 'steal_per_game': '0.9', 'block_per_game': '1.0', 'turnover_per_game': '3.0', 'personal_fouls_per_game': '2.5', 'points_per_game': '19.6'}, {'name': 'Avery Bradley', 'position': 'SG', 'age': '30', 'games': '10', 'games_started': '1', 'minutes_played_per_game': '21.1', 'field_goal_per_game': '3.1', 'field_goal_attempt_per_game': '6.6', 'field_goal_percent_per_game': '.470', 'three_points_field_goal_per_game': '1.6', 'three_points_field_goal_attempt_per_game': '3.8', 'three_points_field_goal_percent_per_game': '.421', 'two_points_field_goal_per_game': '1.5', 'two_points_field_goal_attempt_per_game': '2.8', 'two_points_field_goal_percent_per_game': '.536', 'effective_field_goal_percent_per_game': '.591', 'free_throws_per_game': '0.7', 'free_throws_attempt_per_game': '0.9', 'free_throws_percent_per_game': '.778', 'offensive_rebound_per_game': '0.2', 'defensive_rebound_per_game': '1.6', 'total_rebound_per_game': '1.8', 'assists_per_game': '1.4', 'steal_per_game': '0.7', 'block_per_game': '0.1', 'turnover_per_game': '0.9', 'personal_fouls_per_game': '2.6', 'points_per_game': '8.5'}, {'name': 'Jimmy Butler', 'position': 'SF', 'age': '31', 'games': '19', 'games_started': '19', 'minutes_played_per_game': '32.9', 'field_goal_per_game': '5.9', 'field_goal_attempt_per_game': '13.8', 'field_goal_percent_per_game': '.431', 'three_points_field_goal_per_game': '0.2', 'three_points_field_goal_attempt_per_game': '1.3', 'three_points_field_goal_percent_per_game': '.160', 'two_points_field_goal_per_game': '5.7', 'two_points_field_goal_attempt_per_game': '12.5', 'two_points_field_goal_percent_per_game': '.460', 'effective_field_goal_percent_per_game': '.439', 'free_throws_per_game': '7.0', 'free_throws_attempt_per_game': '8.2', 'free_throws_percent_per_game': '.858', 'offensive_rebound_per_game': '2.0', 'defensive_rebound_per_game': '5.6', 'total_rebound_per_game': '7.6', 'assists_per_game': '7.6', 'steal_per_game': '1.8', 'block_per_game': '0.4', 'turnover_per_game': '2.3', 'personal_fouls_per_game': '1.2', 'points_per_game': '19.1'}, {'name': 'Goran Dragić', 'position': 'PG', 'age': '34', 'games': '17', 'games_started': '6', 'minutes_played_per_game': '26.5', 'field_goal_per_game': ' ...
